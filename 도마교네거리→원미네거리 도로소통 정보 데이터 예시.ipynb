# %% [markdown]
# ### 도로소통 정보 데이터 예시

# %%
from matplotlib import pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
csv = pd.read_csv('D:/download/프로젝트_download/지도/도로소통 정보 데이터/8_31_9_4_데이터.csv', encoding = "CP949")
csv.head()
# Out:
#               일자   도로   요일   방향               구간  6:00  6:05  6:10  6:15  \
# 0            NaN  NaN  NaN  NaN              NaN   NaN   NaN   NaN   NaN
# 1  2020년 08월 31일  가장로  월요일   상행     도마교네거리→원미네거리  14.0  12.2  10.7  12.6
# 2  2020년 08월 31일  가장로  월요일   상행      원미네거리→도마네거리  31.3  30.3  29.0  31.1
# 3  2020년 08월 31일  가장로  월요일   상행    도마네거리→조흥은행네거리  18.5  20.8  17.2  16.2
# 4  2020년 08월 31일  가장로  월요일   상행  조흥은행네거리→매일약국(단)  27.3  29.3  24.5  21.8
#
#    6:20  ...  7:10  7:15  7:20  7:25  7:30  7:35  7:40  7:45  7:50  7:55
# 0   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  14.2  ...   9.4   9.6  11.0  10.5   9.8  11.5  10.7  12.3  10.1   9.2
# 2  31.0  ...  27.0  28.3  24.6  23.4  23.5  19.9  21.7  19.6  20.8  20.1
# 3  16.7  ...  16.1  13.5  12.2  10.6  12.4  11.0  12.5  10.3   9.2   9.2
# 4  25.6  ...  19.1  22.1  23.3  26.5  25.9  22.1  25.3  20.8  18.6  16.3
#
# [5 rows x 29 columns]

# %%
data = csv[csv['구간'] == "도마교네거리→원미네거리"]
data
# Out:
#                일자   도로   요일  방향            구간  6:00  6:05  6:10  6:15  6:20  \
# 1   2020년 08월 31일  가장로  월요일  상행  도마교네거리→원미네거리  14.0  12.2  10.7  12.6  14.2
# 17  2020년 09월 01일  가장로  화요일  상행  도마교네거리→원미네거리  11.6  11.5  11.7  10.3  10.4
# 33  2020년 09월 02일  가장로  수요일  상행  도마교네거리→원미네거리  11.3  12.2  13.9  14.1  12.6
# 49  2020년 09월 03일  가장로  목요일  상행  도마교네거리→원미네거리  12.5  11.2  10.4  11.9   9.8
# 65  2020년 09월 04일  가장로  금요일  상행  도마교네거리→원미네거리  11.7  12.1  10.2  11.0  12.0
#
#     ...  7:10  7:15  7:20  7:25  7:30  7:35  7:40  7:45  7:50  7:55
# 1   ...   9.4   9.6  11.0  10.5   9.8  11.5  10.7  12.3  10.1   9.2
# 17  ...  12.1  10.6  11.9  12.0  10.5   9.2  10.4  11.7   9.7   8.7
# 33  ...   7.9   9.2  10.4  10.3  11.9   9.8   9.0   9.2  10.6   9.5
# 49  ...  11.4   9.4   9.3   8.1   9.6   9.9   8.3   9.9   8.9   8.6
# 65  ...  11.0   9.7  10.7  11.4  11.9  12.2  12.3  11.7  10.1   9.1
#
# [5 rows x 29 columns]

# %%
data = data.iloc[:,5:]
data
# Out:
#     6:00  6:05  6:10  6:15  6:20  6:25  6:30  6:35  6:40  6:45  ...  7:10  \
# 1   14.0  12.2  10.7  12.6  14.2  12.7  14.6  14.6  13.8  12.8  ...   9.4
# 17  11.6  11.5  11.7  10.3  10.4  11.9  13.4  12.3  13.4  13.4  ...  12.1
# 33  11.3  12.2  13.9  14.1  12.6  11.7  10.1   9.5  11.0   9.8  ...   7.9
# 49  12.5  11.2  10.4  11.9   9.8  11.7  13.1  12.5  10.8   9.6  ...  11.4
# 65  11.7  12.1  10.2  11.0  12.0  12.0  13.2  12.3  12.0  10.2  ...  11.0
#
#     7:15  7:20  7:25  7:30  7:35  7:40  7:45  7:50  7:55
# 1    9.6  11.0  10.5   9.8  11.5  10.7  12.3  10.1   9.2
# 17  10.6  11.9  12.0  10.5   9.2  10.4  11.7   9.7   8.7
# 33   9.2  10.4  10.3  11.9   9.8   9.0   9.2  10.6   9.5
# 49   9.4   9.3   8.1   9.6   9.9   8.3   9.9   8.9   8.6
# 65   9.7  10.7  11.4  11.9  12.2  12.3  11.7  10.1   9.1
#
# [5 rows x 24 columns]

# %%
csv1 = pd.read_csv('D:/download/프로젝트_download/지도/도로소통 정보 데이터/9_7_검증데이터.csv', encoding = "CP949")
csv1.iloc[1:,:]
# Out:
#               일자   도로   요일  방향            구간  6:00  6:05  6:10  6:15  6:20  \
# 1  2020년 09월 07일  가장로  월요일  상행  도마교네거리→원미네거리  14.0  16.2  13.3  13.6  15.6
#
#    ...  7:10  7:15  7:20  7:25  7:30  7:35  7:40  7:45  7:50  7:55
# 1  ...  10.8   9.2   9.5  10.8   9.9   9.7   9.6   8.5   8.4   7.6
#
# [1 rows x 29 columns]

# %%
data.append(csv1.iloc[1:,5:])
data.reset_index(drop=True, inplace = True)

# %%
data.plot()

# %%
plt.rcParams['figure.figsize'] = [13, 5]   # 그래프크기

# %%
data = data.T

# %%
data.index
# Out:
# Index(['6:00', '6:05', '6:10', '6:15', '6:20', '6:25', '6:30', '6:35', '6:40',
#        '6:45', '6:50', '6:55', '7:00', '7:05', '7:10', '7:15', '7:20', '7:25',
#        '7:30', '7:35', '7:40', '7:45', '7:50', '7:55'],
#       dtype='object')

# %%
data.plot()
plt.xticks(range(0,len(data.index)),data.index)
plt.grid()
plt.show()

# %%
data
# Out:
#          0     1     2     3     4
# 6:00  14.0  11.6  11.3  12.5  11.7
# 6:05  12.2  11.5  12.2  11.2  12.1
# 6:10  10.7  11.7  13.9  10.4  10.2
# 6:15  12.6  10.3  14.1  11.9  11.0
# 6:20  14.2  10.4  12.6   9.8  12.0
# 6:25  12.7  11.9  11.7  11.7  12.0
# 6:30  14.6  13.4  10.1  13.1  13.2
# 6:35  14.6  12.3   9.5  12.5  12.3
# 6:40  13.8  13.4  11.0  10.8  12.0
# 6:45  12.8  13.4   9.8   9.6  10.2
# 6:50  12.2  13.6   9.4  11.3   9.9
# 6:55  11.6  13.6   9.4  11.5  10.8
# 7:00  10.0  11.6  10.7   9.7  12.3
# 7:05   8.8  10.3   8.8   9.9  10.6
# 7:10   9.4  12.1   7.9  11.4  11.0
# 7:15   9.6  10.6   9.2   9.4   9.7
# 7:20  11.0  11.9  10.4   9.3  10.7
# 7:25  10.5  12.0  10.3   8.1  11.4
# 7:30   9.8  10.5  11.9   9.6  11.9
# 7:35  11.5   9.2   9.8   9.9  12.2
# 7:40  10.7  10.4   9.0   8.3  12.3
# 7:45  12.3  11.7   9.2   9.9  11.7
# 7:50  10.1   9.7  10.6   8.9  10.1
# 7:55   9.2   8.7   9.5   8.6   9.1
